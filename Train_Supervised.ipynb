# %% [markdown]
# This notebook can be ONLY used for:
#
# 1. Calculating the performance **upper bound: change pct_data = 1**.
# 2. Calculating the performance **lower bound: change pct_data = supervised data %**.
#
# Make sure to add whatever file path you think will be more convinient. In my case, for each model I created a folder, and 3 subfolders, one for the LB, UP and Mean Teacher. If you choose this method, **make sure the folders are created beforehand**. Otherwise, feel free to do whatever. For this notebook, the following things will be saved:
#
# 1. The weights of the model every 5 epochs (./whatever_name_you_want_epoch_X).
# 2. Running loss during training (every epoch).
# 3. Accuracy and IOU on train set every 5 epochs.
# 4. Accuracy and IOU on validation set every 5 epochs.
#
# **If you use this notebook directly from colab, PLEASE make a copy and don't change anything in the original file, cuz then my kernel will crash :(**.
#
# **NOTE: This file uses a modified version of the dataloader in GitHub. If you run it with that one you will get an attribute error from get_data.**

# %%
# ONLY PARAMETER THAT SHOULD BE CHANGED. 
pct_data = 1 # Total amount of data the model will see. This is to calculate the LB (or UB) for the performance of the model. All labeled.
model_save_path = "./M2_29_03_23/M2_UB/"

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %ls
# Out:
# gdrive/  sample_data/

# %%
# %cd /content/gdrive/MyDrive/Applied DL CW
# Out:
# /content/gdrive/MyDrive/Applied DL CW

# %%
# %ls
# Out:
# data/                 M1_28_03_23/   __pycache__/              utils.py
# data_augmentation.py  M2_29_03_23/   Train_Mean_Teacher.ipynb
# data_into_loaders.py  model_UNet.py  Train_Supervised.ipynb

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam, lr_scheduler
import model_UNet
from data_augmentation import augmentation, colorjiter, invert
import matplotlib.pyplot as plt
from data_into_loaders import get_data
from utils import dice_loss, wt, update_ema_variables, unsup_loss, evaluate_model

# %%
#### Do NOT touch these hyperparameters
img_resize = 64
depth, dropout_rate = 3, 0.25 # Depth of U-Net
val_pct, test_pct = 0.2, 0.1 # Validation and test set %. 

# Trainin params
batch_size = 32
epochs = 100
lr, lr_gamma = 1e-3, 0.9 #Optimizer params

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") 
print(f'Using device: {device}')
# Out:
# Using device: cuda:0

# %%
# Initialize models, losses and optimizers. Make sure to re-run this cell again if you stop training and start again
#Create 1 network
modelS = model_UNet.UNet(in_channels=3, num_classes=2, depth=depth)
modelS= modelS.to(device)

#optimizer
optimizer = Adam(modelS.parameters(), lr=lr)
scheduler = lr_scheduler.ExponentialLR(optimizer, gamma=lr_gamma, last_epoch=-1, verbose=True)
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.

# %%
mixed_train_loader, val_loader, test_loader = get_data(0.25,0.75,val_pct, test_pct, batch_size=batch_size, img_resize=img_resize, is_mixed_loader = False, pct_data = pct_data)
# Out:
# all images are =  7393

# %%
# Train
eval_freq = 5
losses, accsTr, IousTr, accsVal, IousVal = [], [], [], [], []

for epoch in range(epochs):

        modelS.train()
        running_loss = 0

        for step, data in enumerate(mixed_train_loader):

            imgs, labs = data
            # Augment images
            imgS_aug = augmentation(imgs)

            imgS_aug = imgS_aug.to(device)
            labs = labs.squeeze().type(torch.LongTensor).to(device)

            optimizer.zero_grad()

            # Forward pass for student and teacher
            z = modelS(imgS_aug) 
            loss = dice_loss(z, labs)
            
            loss.backward()
            
            optimizer.step()    
            running_loss += loss.item()


        print(f'Epoch: {epoch + 1:4d} - Loss: {running_loss:6.2f}')
        losses.append(running_loss)
    
        if (epoch % eval_freq == 0):

          # Get accuracy and IOU for train and validation dataset 
          accTr, IouTr = evaluate_model(modelS, mixed_train_loader, device)
          accVal, IouVal = evaluate_model(modelS, val_loader, device)
          
          accsTr.append(accTr)
          IousTr.append(IouTr)   
          accsVal.append(accVal)
          IousVal.append(IouVal)

          print(f'For training: accuracy-{accTr:2.0%}; IOU-{IouTr:2.0%}')
          print(f'For validation: accuracy-{accVal:2.0%}; IOU-{IouVal:2.0%}')

          np.savetxt(f"{model_save_path}running_loss", losses)
          np.savetxt(f"{model_save_path}train_accuracy", accsTr)
          np.savetxt(f"{model_save_path}train_IOU", IousTr)
          np.savetxt(f"{model_save_path}val_accuracy", accsVal)
          np.savetxt(f"{model_save_path}val_IOU", IousVal)

          torch.save(modelS.state_dict(), f"{model_save_path}model_epoch_{epoch+1}" + '.pt')
# Out:
# Epoch:    1 - Loss:  39.96
# For training: accuracy-80%; IOU-63%
# For validation: accuracy-80%; IOU-63%
# Epoch:    2 - Loss:  31.67
# Epoch:    3 - Loss:  29.66
# Epoch:    4 - Loss:  27.44
# Epoch:    5 - Loss:  26.53
# Epoch:    6 - Loss:  25.40
# For training: accuracy-85%; IOU-69%
# For validation: accuracy-85%; IOU-68%
# Epoch:    7 - Loss:  24.54
# Epoch:    8 - Loss:  24.73
# Epoch:    9 - Loss:  23.98
# Epoch:   10 - Loss:  23.27
# Epoch:   11 - Loss:  22.66
# For training: accuracy-87%; IOU-75%
# For validation: accuracy-87%; IOU-74%
# Epoch:   12 - Loss:  22.19
# Epoch:   13 - Loss:  21.40
# Epoch:   14 - Loss:  21.08
# Epoch:   15 - Loss:  21.10
# Epoch:   16 - Loss:  20.22
# For training: accuracy-89%; IOU-77%
# For validation: accuracy-88%; IOU-76%
# Epoch:   17 - Loss:  20.29
# Epoch:   18 - Loss:  20.40
# Epoch:   19 - Loss:  19.80
# Epoch:   20 - Loss:  19.31
# Epoch:   21 - Loss:  18.62
# For training: accuracy-90%; IOU-78%
# For validation: accuracy-88%; IOU-75%
# Epoch:   22 - Loss:  18.56
# Epoch:   23 - Loss:  18.68
# Epoch:   24 - Loss:  18.15
# Epoch:   25 - Loss:  17.66
# Epoch:   26 - Loss:  17.85
# For training: accuracy-90%; IOU-78%
# For validation: accuracy-88%; IOU-75%
# Epoch:   27 - Loss:  17.67
# Epoch:   28 - Loss:  17.35
# Epoch:   29 - Loss:  16.86
# Epoch:   30 - Loss:  16.52
# Epoch:   31 - Loss:  16.48
# For training: accuracy-91%; IOU-80%
# For validation: accuracy-89%; IOU-76%
# Epoch:   32 - Loss:  15.77
# Epoch:   33 - Loss:  16.33
# Epoch:   34 - Loss:  15.42
# Epoch:   35 - Loss:  15.70
# Epoch:   36 - Loss:  15.03
# For training: accuracy-92%; IOU-81%
# For validation: accuracy-89%; IOU-77%
# Epoch:   37 - Loss:  15.26
# Epoch:   38 - Loss:  14.73
# Epoch:   39 - Loss:  15.95
# Epoch:   40 - Loss:  14.83
# Epoch:   41 - Loss:  14.68
# For training: accuracy-92%; IOU-82%
# For validation: accuracy-89%; IOU-76%
# Epoch:   42 - Loss:  14.25
# Epoch:   43 - Loss:  14.14
# Epoch:   44 - Loss:  14.29
# Epoch:   45 - Loss:  13.76
# Epoch:   46 - Loss:  13.42
# For training: accuracy-92%; IOU-83%
# For validation: accuracy-89%; IOU-77%
# Epoch:   47 - Loss:  13.64
# Epoch:   48 - Loss:  13.58
# Epoch:   49 - Loss:  13.47
# Epoch:   50 - Loss:  13.33
# Epoch:   51 - Loss:  12.91
# For training: accuracy-93%; IOU-84%
# For validation: accuracy-89%; IOU-77%
# Epoch:   52 - Loss:  12.75
# Epoch:   53 - Loss:  12.41
# Epoch:   54 - Loss:  12.39
# Epoch:   55 - Loss:  11.85
# Epoch:   56 - Loss:  12.42
# For training: accuracy-93%; IOU-84%
# For validation: accuracy-89%; IOU-76%
# Epoch:   57 - Loss:  12.27
# Epoch:   58 - Loss:  11.51
# Epoch:   59 - Loss:  12.06
# Epoch:   60 - Loss:  11.73
# Epoch:   61 - Loss:  11.84
# For training: accuracy-93%; IOU-84%
# For validation: accuracy-89%; IOU-76%
# Epoch:   62 - Loss:  11.64
# Epoch:   63 - Loss:  11.34
# Epoch:   64 - Loss:  11.10
# Epoch:   65 - Loss:  11.28
# Epoch:   66 - Loss:  11.04
# For training: accuracy-94%; IOU-86%
# For validation: accuracy-89%; IOU-77%
# Epoch:   67 - Loss:  11.42
# Epoch:   68 - Loss:  11.29
# Epoch:   69 - Loss:  11.68
# Epoch:   70 - Loss:  11.20
# Epoch:   71 - Loss:  11.11
# For training: accuracy-94%; IOU-86%
# For validation: accuracy-89%; IOU-77%
# Epoch:   72 - Loss:  10.47
# Epoch:   73 - Loss:  10.53
# Epoch:   74 - Loss:  10.43
# Epoch:   75 - Loss:  10.97
# Epoch:   76 - Loss:  10.42
# For training: accuracy-94%; IOU-86%
# For validation: accuracy-89%; IOU-77%
# Epoch:   77 - Loss:  10.37
# Epoch:   78 - Loss:  10.52
# Epoch:   79 - Loss:   9.89
# Epoch:   80 - Loss:  10.37
# Epoch:   81 - Loss:  10.24
# For training: accuracy-94%; IOU-86%
# For validation: accuracy-89%; IOU-76%
# Epoch:   82 - Loss:   9.90
# Epoch:   83 - Loss:   9.93
# Epoch:   84 - Loss:   9.81
# Epoch:   85 - Loss:   9.89
# Epoch:   86 - Loss:  10.21
# For training: accuracy-94%; IOU-86%
# For validation: accuracy-89%; IOU-76%
# Epoch:   87 - Loss:   9.59
# Epoch:   88 - Loss:   9.46
# Epoch:   89 - Loss:   9.49
# Epoch:   90 - Loss:   9.78
# Epoch:   91 - Loss:   9.66
# For training: accuracy-94%; IOU-87%
# For validation: accuracy-89%; IOU-76%
# Epoch:   92 - Loss:   9.92
# Epoch:   93 - Loss:   9.57
# Epoch:   94 - Loss:   9.40
# Epoch:   95 - Loss:   9.43
# Epoch:   96 - Loss:   9.15
# For training: accuracy-94%; IOU-87%
# For validation: accuracy-89%; IOU-77%
# Epoch:   97 - Loss:   9.34
# Epoch:   98 - Loss:   9.22
# Epoch:   99 - Loss:   9.29
# Epoch:  100 - Loss:   9.13
